# %% [markdown]
# # Análise de sentimento aplicada a textos com Machine Learning
# ***Autor:***  Oldaque Rios

# %% [markdown]
# O código escrito em linguagem Python a seguir utilizará técnicas de Machine Learning e NLP (Natural Language Processing) e também apresentará a criação de um modelo (estimator) que, através do aprendizado supervisionado de máquina (supervised machine learning) realizará uma análise de sentimento de um texto classificando-o como: Sentimento positivo, sentimento negativo e sentimento neutro. Este código também será utilizando em um projeto um projeto pessoal chamado AoNS (Analysis of News Sentiment) que apresenta um dashboard com KPI's da análise de sentimento dos títulos e resumos das notícias dos principais portais do Brasil.

# %%
from IPython.display import HTML

HTML('<center><h1>Como ensinar uma máquina a aprender?</h1>'
     '<br><iframe width="560" height="315" src="https://www.youtube.com/embed/mhe5e2B9bL8" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')

# %% [markdown]
# ### Entendendo sobre o ML (Machine Learning)
#
# Indico o vídeo acima para entender como funciona o processo de aprendizado de máquina, pois acredito que ele seja bem didático e até mesmo pessoas que não sabem o que é um modelo matemático para aprendizado de máquinas (como, por exemplo: regressão linear, regressão múltipla, regressão logística entre outros) conseguem enxergar que, na verdade, quando um algoritmo criado aprende a executar determinada ação, o real funcionamento não é um grande código fonte
#  cheio de condicionas (IF/SE) e, na verdade seria como uma função matemática percorrendo por caminhos lógicos que são criados a partir dos dados que ele analisa, ou seja, basicamente seria uma função matemática (f) que através das características dos dados (x) chega a um resultado (y).
#
# f
# (x) = y
#
#
# * f — Estimator (ou estimador) é o algoritmo que é gerado através do processo de ML;
#
# * x — Features (ou características) é o que caracteriza nossos dados;
#
# * y — Class (ou classe) é o resultado da nossa função, aquilo que segundo a função, o algoritmo decide como resultado.
#
# Por fim, para simplificar e trazer um exemplo da nossa realidade, vamos supor que você voltou no tempo e está no primeiro ano da escola e ao chegar na classe é aula de artes, a professora chega e pede um desenho do céu e para isso você precisará de 3 lápis de cores diferentes: azul, branco e amarelo. Você abre o estojo e vê aquela coleção de lápis com mais de 32 cores e precisa decidir os lápis corretos para ganhar sua primeira nota 10, para isso seu cérebro automaticamente desenha um algoritmo pegar apenas os lápis (função) onde a decisão (y) é baseada nas características (features: azul, branco e amarelo) do desenho solicitado. Isso tudo acontece de forma inconsciente, pois um dia você aprendeu o que era céu e suas características e também a identificar e diferenciar cores seja com alguém te ensinando através de uma exposição as cores (aprendizado supervisionado) te mostrando o que era azul, branco e amarelo. Também há outros modelos de ML, para conhecer mais indico <a href="https://lamfo-unb.github.io/2017/07/27/tres-tipos-am/">esse artigo</a>.

# %% [markdown]
# ## Importando biblíotecas

# %% [markdown]
# Para construir nosso modelo será utilizado as seguintes bibliotecas (e seus módulos):
#
# *  Pandas
#
# *  ScikitLearn (sklearn)
#
# *  Matplotlib
#
# *  WordCloud
#
# *  Seaborn
#
# *  String
#
# *  Unidecode

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import nltk
from nltk import FreqDist
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import WhitespaceTokenizer
from nltk import ngrams
from string import punctuation
from unidecode import unidecode
# Out:
# C:\Users\oldaq\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Definindo funções

# %%
# Looking for specific terms
def count_by_terms(data, column_text, term_list):
    qtd_terms = []
    for term in term_list:
        term_index = [index for index, text in enumerate(data[column_text]) if term in text.lower()]
        term_freq = len(term_index)
        qtd_terms.append(term_freq)
    return pd.DataFrame({'Termo': term_list, 
                         'Frequencia' : qtd_terms})

# Making word clouds
def word_cloud(data, text_column, query=False, query_code=''):
    if not query:
        filter_text = data
    else:
        filter_text = data.query(query_code)

    all_words_list = ' '.join([text for text in filter_text[text_column]])
    word_cloud = WordCloud(width=800, height=500,  # Definindo espaço do texto
                        max_font_size=110
                        ).generate(all_words_list)

    plt.figure(figsize=(10,7))  # Definindo tamanho da imagem
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Bars plot with the most frequent words
def freq_words_plot(data, text_column, qnt_word):
    
    all_words_list = ' '.join([text for text in data[text_column]])
    token = WordPunctTokenizer()
    sentence_token = token.tokenize(all_words_list)
    
    frequence_of_words = FreqDist(sentence_token)
    df_word_freq = pd.DataFrame({'palavra' : list(frequence_of_words.keys()),
                                'frequencia': list(frequence_of_words.values())})

    top_words = df_word_freq.nlargest(columns='frequencia', 
                                      n=qnt_word)

    plt.figure(figsize=(12,8))
    ax = sns.barplot(data= top_words,
                     x = top_words['palavra'], y = top_words['frequencia'],
                     color = 'darkviolet')
    ax.set(ylabel='Contagem')
    plt.show()

# Returns the accuracy's score 
def accuracy_model(dataset_text, text_column, class_column, seed):

    vetorizar_tfidf = TfidfVectorizer(lowercase=False, ngram_range=(1, 2))
    tfidf = vetorizar_tfidf.fit_transform(dataset_text[text_column])
    
    SEED = seed

    x_train, x_test, y_train, y_test = train_test_split(tfidf, 
                                                        dataset_text[class_column],
                                                        test_size = 0.25,
                                                        stratify = dataset_text[class_column],
                                                        random_state = SEED)

    model = LogisticRegression(random_state= SEED)
    model.fit(x_train, y_train)
    accuracy = model.score(x_test, y_test)
    return accuracy

# Modeling and transform text
def transform_text(data, column_text, stopwords_data, new_column_name):
    all_of_words = []
    for tweet in data[column_text]:
        new_sentence = []
        tweet = tweet.lower()
        
        '''Removing the usersnames find @ in the word's begin'''
        token = WhitespaceTokenizer()
        sentence_token = token.tokenize(tweet)
        for word in sentence_token:
            if word[0] == '@':
                continue
            word = unidecode(word)
            new_sentence.append(word)
        sentence_without_user = ' '.join(new_sentence)

        '''Transforming text removing stopwords and accents'''
        new_sentence = []
        token = WordPunctTokenizer()
        sentence_token = token.tokenize(sentence_without_user)
        for word in sentence_token:
            if word not in stopwords_data:  # Removing stopwords
                new_sentence.append(nltk.RSLPStemmer().stem(word))  # Applying Stem to words
        all_of_words.append(' '.join(new_sentence))

    data[new_column_name] = all_of_words

# %% [markdown]
# ## Importando datasets

# %% [markdown]
# Neste projeto será utilizado o dataset que você pode encontrar na plataforma Kraggle <a href="https://www.kaggle.com/augustop/portuguese-tweets-for-sentiment-analysis">clicando aqui</a>, nele encontraremos mais de 800k de tweets em português com as suas classificações de sentimento.

# %%
df_tweets_neutral = pd.read_csv('dataset/TweetsNeutralNews.csv')
df_tweets_neutral.head()
# Out:
#                     id                                         tweet_text  \
# 0  1038992008461930496  Esquerda e direita empatam na Suécia; ultranac...
# 1  1038873557902782465  Ao vivo: Estadão e TV Gazeta realizam terceiro...
# 2  1038869931398516736  FOTOS: Apoiadores de Jair Bolsonaro realizam a...
# 3  1038867128886198273  Barroso ameaça barrar propaganda se PT insisti...
# 4  1038859914339409920  Serena Williams é multada pelo comportamento d...
#
#                        tweet_date sentiment query_used
# 0  Mon Sep 10 03:26:13 +0000 2018    Neutro       veja
# 1  Sun Sep 09 19:35:32 +0000 2018    Neutro       veja
# 2  Sun Sep 09 19:21:07 +0000 2018    Neutro       veja
# 3  Sun Sep 09 19:09:59 +0000 2018    Neutro       veja
# 4  Sun Sep 09 18:41:19 +0000 2018    Neutro       veja

# %%
df_tweets_neutral.sentiment.value_counts()
# Out:
# Neutro    37556
# Name: sentiment, dtype: int64

# %%
# Looking for bad terms 
term_list = ['morr', 'mort', 'trist', 'sofr', 'aband', 'guerra']
bad_words = count_by_terms(df_tweets_neutral, 'tweet_text', term_list)
bad_words
# Out:
#     Termo  Frequencia
# 0    morr         592
# 1    mort        1042
# 2   trist          29
# 3    sofr         174
# 4   aband          77
# 5  guerra         171

# %%
# Change bad terms to negative sentiment
for index, row in df_tweets_neutral.iterrows():
    for term in term_list:
        if (term in row['tweet_text']):
            df_tweets_neutral.loc[index, 'sentiment'] = 'neg'

# %%
df_tweets_neutral = df_tweets_neutral.loc[df_tweets_neutral['sentiment'] == 'neg']

# %%
df_tweets_neutral.sentiment.value_counts()
# Out:
# neg    1746
# Name: sentiment, dtype: int64

# %%
df_reviews_imdb = pd.read_csv('dataset/imdb-reviews-pt-br.csv')
df_reviews_imdb.head()
# Out:
#    id                                            text_en  \
# 0   1  Once again Mr. Costner has dragged out a movie...
# 1   2  This is an example of why the majority of acti...
# 2   3  First of all I hate those moronic rappers, who...
# 3   4  Not even the Beatles could write songs everyon...
# 4   5  Brass pictures movies is not a fitting word fo...
#
#                                              text_pt sentiment
# 0  Mais uma vez, o Sr. Costner arrumou um filme p...       neg
# 1  Este é um exemplo do motivo pelo qual a maiori...       neg
# 2  Primeiro de tudo eu odeio esses raps imbecis, ...       neg
# 3  Nem mesmo os Beatles puderam escrever músicas ...       neg
# 4  Filmes de fotos de latão não é uma palavra apr...       neg

# %%
df_reviews_imdb.sentiment.value_counts()
# Out:
# neg    24765
# pos    24694
# Name: sentiment, dtype: int64

# %%
# Standardizing datasets
df_tweets_neutral = df_tweets_neutral.loc[:, ['tweet_text', 'sentiment']]
df_tweets_neutral = df_tweets_neutral.rename(columns={'tweet_text': 'text'})
df_tweets_neutral.head()
# Out:
#                                                  text sentiment
# 23  Confrontos entre curdos e forças do regime sír...       neg
# 27  Irmão da ex-ginasta Lais Souza morre durante p...       neg
# 31  Chega a 35 número de mortos por terremoto no J...       neg
# 44  Brasileiro e venezuelano morrem após suspeita ...       neg
# 47  Rapper Mac Miller é encontrado morto aos 26 an...       neg

# %%
# Standardizing datasets
df_reviews_imdb = df_reviews_imdb.loc[:, ['text_pt', 'sentiment']]
df_reviews_imdb = df_reviews_imdb.rename(columns={'text_pt': 'text'})
df_reviews_imdb.head()
# Out:
#                                                 text sentiment
# 0  Mais uma vez, o Sr. Costner arrumou um filme p...       neg
# 1  Este é um exemplo do motivo pelo qual a maiori...       neg
# 2  Primeiro de tudo eu odeio esses raps imbecis, ...       neg
# 3  Nem mesmo os Beatles puderam escrever músicas ...       neg
# 4  Filmes de fotos de latão não é uma palavra apr...       neg

# %%
'''df_negative = df_reviews_imdb.loc[df_tweets_geral['sentiment'] == 'neg']
df_negative = df_negative[15000]
df_positive = df_reviews_imdb.loc[df_tweets_geral['sentiment'] == 'pos']
df_positive = df_positive[15000]'''
# Out:
# "df_negative = df_reviews_imdb.loc[df_tweets_geral['sentiment'] == 'neg']\ndf_negative = df_negative[15000]\ndf_positive = df_reviews_imdb.loc[df_tweets_geral['sentiment'] == 'pos']\ndf_positive = df_positive[15000]"

# %%
frames = [df_reviews_imdb, df_tweets_neutral[:30000]]
df_sentiments = pd.concat(frames, ignore_index=True)
df_sentiments.sentiment.value_counts()
# Out:
# neg    26511
# pos    24694
# Name: sentiment, dtype: int64

# %%
to_binary = {
    'pos' : 1,
    'neg' : 0,
    'Neutro' : 2
}

df_sentiments['sentiment'] = df_sentiments.sentiment.map(to_binary)

# %%
freq_words_plot(df_sentiments, 'text', 15)

# %%
word_cloud(df_sentiments, 'text')

# %%
stop_words = nltk.corpus.stopwords.words('portuguese')
punctuations = [x for x in punctuation]
stop_words.extend(punctuations)
stop_words.extend(['https', '://', ':(', ':)', ':((', ':(((', 'co', 't', 'to', 
                   'q', 'ai', ':(((', 't', 'gt', ';@', 'r', 'd', 'p', '–', 
                   ':))', '...', 'n', "',", 'filme'])  # Chars identified in text
stop_words = [unidecode(char) for char in stop_words]
stop_words = list(set(stop_words))

# %%
transform_text(df_sentiments, 'text', stop_words, 'transformed_text')
df_sentiments.head()
# Out:
#                                                 text  sentiment  \
# 0  Mais uma vez, o Sr. Costner arrumou um filme p...          0
# 1  Este é um exemplo do motivo pelo qual a maiori...          0
# 2  Primeiro de tudo eu odeio esses raps imbecis, ...          0
# 3  Nem mesmo os Beatles puderam escrever músicas ...          0
# 4  Filmes de fotos de latão não é uma palavra apr...          0
#
#                                     transformed_text
# 0  vez sr costn arrum temp necessari alem terri s...
# 1  exempl motiv maior film aca mesm gener chat na...
# 2  prim tud odei rap imbecil pod agir arm pressio...
# 3  beatl pud escrev music tod gost emb walt hill ...
# 4  film fot lata palavr apropri verdad tant ous q...

# %%
df_sentiments.to_csv('dataset_nlp.csv')

# %%
# Sentimentos positivos WordCloud
word_cloud(df_sentiments, 'transformed_text', query=True, query_code='sentiment == 1')

# %%
# Sentimentos neutros WordCloud
word_cloud(df_sentiments, 'transformed_text', query=True, query_code='sentiment == 2')

# %%
# Sentimentos negativos WordCloud
word_cloud(df_sentiments, 'transformed_text', query=True, query_code='sentiment == 0')

# %%
freq_words_plot(df_sentiments, 'transformed_text', 15)

# %%
# Baseline - Algoritmo de comparação

vetorizar = CountVectorizer()
bag_of_words = vetorizar.fit_transform(df_sentiments['text'])
    
SEED = 36

x_train, x_test, y_train, y_test = train_test_split(bag_of_words, 
                                                    df_sentiments['sentiment'],
                                                    test_size = 0.25,
                                                    stratify = df_sentiments['sentiment'],
                                                    random_state = SEED)

model_baseline = LogisticRegression(random_state= SEED)
model_baseline.fit(x_train, y_train)
accuracy_baseline = model_baseline.score(x_test, y_test)


print(f'Acurácia de: {accuracy_baseline * 100:.2f}%')
# Out:
# C:\Users\oldaq\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Acurácia de: 88.28%

# %%
acc_model = accuracy_model(df_sentiments, 'transformed_text', 'sentiment', 16)
print(f'Acurácia de: {acc_model * 100:.2f}%')

# %%
vetorizar_tfidf = TfidfVectorizer(lowercase=False, ngram_range=(1, 3))
tfidf = vetorizar_tfidf.fit_transform(df_sentiments['transformed_text'])
    
SEED = 16

x_train, x_test, y_train, y_test = train_test_split(tfidf, 
                                                    df_sentiments['sentiment'],
                                                    test_size = 0.25,
                                                    stratify = df_sentiments['sentiment'],
                                                    random_state = SEED)

model = LogisticRegression(solver='lbfgs')
model.fit(x_train, y_train)
accuracy_baseline = model.score(x_test, y_test)


print(f'Acurácia de: {accuracy_baseline * 100:.2f}%')
# Out:
# Acurácia de: 88.22%

# %%
pesos = pd.DataFrame(
    model.coef_[0].T,
    index = vetorizar_tfidf.get_feature_names()
)

pesos.nlargest(50, 0)
# Out:
#                     0
# otim        10.621157
# excel        9.736237
# maravilh     7.259766
# perfeit      7.136807
# favorit      6.358772
# divert       6.021880
# incri        5.985592
# ador         4.984069
# brilh        4.969250
# recom        4.653720
# am           4.574711
# vid          4.573638
# melhor       4.553919
# hoj          4.497090
# definitiv    4.380457
# agrada       4.348238
# aind         4.320973
# bom          4.217604
# bem          4.084389
# gost         4.080064
# dvd          3.983639
# lind         3.945156
# impression   3.931651
# surpreend    3.858750
# sempr        3.841294
# class        3.819142
# hilari       3.784612
# fantas       3.777751
# fort         3.723976
# comov        3.705612
# muit         3.677436
# grand        3.670664
# performanc   3.646058
# soberb       3.624302
# difer        3.444556
# ame          3.414004
# 10 10        3.383008
# bem feit     3.358469
# espec        3.306147
# trabalh      3.221297
# ...

# %%
testes = ['Média móvel mostra aumento de mortes por Covid em 9 estados e no DF Entenda como o índice divulgado pelo G1 é calculado',
          'Brasil tem 72.921 mortes e mais de 1,8 milhão de casos',
          'Advogados pedem que STF arquive ação contra foro de Flávio Bolsonaro',
          'Lei que multa quem não usar máscara no estado do RJ começa a valer',
          'Procuradoria pede que STJ solte ex-secretário de Saúde do RJ',
          'Carnaval de Salvador pode ser adiado se não houver vacina, diz prefeito',
          'Governo deposita hoje mais R$ 15 bi para estados e municípios',
          'Casa de PC Siqueira é alvo da polícia após acusação de pornografia infantil',
          'Maldição? Veja lista com outras tragédias envolvendo o elenco de "Glee"',
          'Cliente encontra dedo humano em esfiha em SP',
          'Brasileira é salva por método de ventilação que ela própria criou',
          'SP libera aulas de idioma com até 35% da capacidade',
          'Peritos vão ao prédio de jovem picado por naja e analisam imagens',
          'Tigre e leão fazem teste de Covid-19 em zoológico no Paraná',
          'Melhor filme da minha vida'
         ]

freq_words_text = vetorizar_tfidf.transform(testes)

for t, c in zip (testes,model.predict(freq_words_text)):
    # t representa o tweet e c a classificação de cada tweet.
    print(f'{t}: {c}')
# Out:
# Média móvel mostra aumento de mortes por Covid em 9 estados e no DF Entenda como o índice divulgado pelo G1 é calculado: 0
# Brasil tem 72.921 mortes e mais de 1,8 milhão de casos: 1
# Advogados pedem que STF arquive ação contra foro de Flávio Bolsonaro: 0
# Lei que multa quem não usar máscara no estado do RJ começa a valer: 0
# Procuradoria pede que STJ solte ex-secretário de Saúde do RJ: 0
# Carnaval de Salvador pode ser adiado se não houver vacina, diz prefeito: 0
# Governo deposita hoje mais R$ 15 bi para estados e municípios: 0
# Casa de PC Siqueira é alvo da polícia após acusação de pornografia infantil: 0
# Maldição? Veja lista com outras tragédias envolvendo o elenco de "Glee": 0
# Cliente encontra dedo humano em esfiha em SP: 0
# Brasileira é salva por método de ventilação que ela própria criou: 0
# SP libera aulas de idioma com até 35% da capacidade: 0
# Peritos vão ao prédio de jovem picado por naja e analisam imagens: 0
# ...

# %%
freq_words_text2 = vetorizar.transform(testes)

for t, c in zip (testes,model_baseline.predict(freq_words_text2)):
    # t representa o tweet e c a classificação de cada tweet.
    print(f'{t}: {c}')
